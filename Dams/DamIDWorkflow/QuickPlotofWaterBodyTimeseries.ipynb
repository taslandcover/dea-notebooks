# %% [markdown]
# # Quick Plot of Water Body Timeseries

# %%
# %pylab notebook

import xarray as xr
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Which water body data would you like to plot up?

# %%
WaterID = 33388

# %% [markdown]
# ## Plot it!

# %%
WaterBodyOfInterest = str(WaterID)

# TimeHistory = pd.read_csv(r'G:\AR2\Crc\ClimateUnit\Projects\EDIS\WOfS_farmdams\timeseries\{}.txt'.format(WaterBodyOfInterest))
TimeHistory = pd.read_csv('/g/data/r78/cek156/dea-notebooks/Dams/Dams2000to2018/Timeseries_new2/{}.txt'.format(WaterBodyOfInterest))

c=list(TimeHistory.head(0))[1];
c2=c[c.find("(")+1:c.find(")")]

TimeHistory['Observation Date'] = pd.to_datetime(TimeHistory['Observation Date'])

plt.figure(figsize = [7,5])
plt.plot(TimeHistory['Observation Date'], TimeHistory['Wet pixel percentage'])
# plt.xlim(2000,2018)
plt.xlabel('Year')
plt.ylabel('Percentage full')
plt.title('Water Body ID: {}, Pixel Count ({})'.format(WaterBodyOfInterest,c2))
# Out:
# <img src="data:image/png;base64,..." width="700">
# Text(0.5,1,'Water Body ID: 33388, Pixel Count (n = 236)')

# %%
TimeHistory['Observation Date'].diff().mean()
# Out:
# Timedelta('8 days 20:39:18.097348')
